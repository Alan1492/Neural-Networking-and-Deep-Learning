# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the input range that is containing 100 evenly spaced numbers from -10 to 10
x = np.linspace(-10, 10, 100)

# Step Function
def step_function(x):
    return np.where(x >= 0, 1, 0)

# Sigmoid Function (Binary)
def sigmoid_function(x):
    return 1 / (1 + np.exp(-x))

# Tanh Function (Bipolar Sigmoid)
# The Tanh function is the most common type of bipolar sigmoid function.
def tanh_function(x):
    return np.tanh(x)

# ReLU Function (Rectified Linear Unit)
def relu_function(x):
    return np.maximum(0, x)

# Calculating outputs for each function
step = step_function(x)
sigmoid = sigmoid_function(x)
tanh = tanh_function(x)
relu = relu_function(x)

# Visualizing the activation functions using plots
plt.style.use('seaborn-v0_8-whitegrid')
fig, ax = plt.subplots(figsize=(12, 7))

ax.plot(x, step, label='Step Function', lw=2)
ax.plot(x, sigmoid, label='Sigmoid Function', lw=2)
ax.plot(x, tanh, label='Tanh Function', lw=2)
ax.plot(x, relu, label='ReLU Function', lw=2)

ax.set_title('Comparing the activation functions', fontsize=16)
ax.set_xlabel('Input Value (x)', fontsize=12)
ax.set_ylabel('Output Value', fontsize=12)
ax.legend(fontsize=12)
ax.axhline(0, color='black', linewidth=0.5)
ax.axvline(0, color='black', linewidth=0.5)
plt.show()

# %%
import numpy as np
from sklearn.neural_network import MLPClassifier

# defining dataset for the XOR problem
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 1, 1, 0])

# activation functions to test
# here the sigmoid function is called logistic
activation_functions = ['logistic', 'tanh', 'relu']

print("Training the Simple Neural Network on the XOR Problem\n")

#Loop through each activation function, train a model, and evaluate it
for activation in activation_functions:
    print(f"####<<<Testing with '{activation.upper()}' activation function>>>####")

    # Create a Multi-layer Perceptron (MLP) classifier
    # hidden_layer_sizes=(4,): One hidden layer with 4 neurons.
    # solver=adam: An efficient solver for large datasets.
    # random_state: Ensures reproducible results.
    model = MLPClassifier(hidden_layer_sizes=(4,),
                          activation=activation,
    # here we can also use the lbfgs which can be efficient for smaller dataset
                          solver='adam',
                          random_state=1,
    # i gave the iteration like 2500 because while giving the smaller values like (1000 or 2000) the model gave a warning that it ran out of training time before it could find the best solution
                          max_iter=2500)

    # Training the model
    model.fit(X, y)

    # Making  predictions
    predictions = model.predict(X)

    # calculating accuracy
    accuracy = model.score(X, y) * 100

    print(f"Input Data:\n{X}")
    print(f"Predicted Outputs: {predictions}")
    print(f"Actual Outputs:    {y}")
    print(f"Accuracy: {accuracy:.2f}%\n")
# Out:
# Training the Simple Neural Network on the XOR Problem
#
# ####<<<Testing with 'LOGISTIC' activation function>>>####
# Input Data:
# [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
# Predicted Outputs: [0 0 0 0]
# Actual Outputs:    [0 1 1 0]
# Accuracy: 50.00%
#
# ####<<<Testing with 'TANH' activation function>>>####
# Input Data:
# [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
# Predicted Outputs: [0 1 1 0]
# Actual Outputs:    [0 1 1 0]
# Accuracy: 100.00%
#
# ####<<<Testing with 'RELU' activation function>>>####
# Input Data:
# [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
# Predicted Outputs: [0 1 1 0]
# Actual Outputs:    [0 1 1 0]
# Accuracy: 100.00%
